# %%
from pycaret.classification import setup, compare_models, pull
import pandas as pd

# %%
df = pd.read_csv("../../data_p2/전처리v1.csv", encoding='utf-8')

# %%
setup(data=df, target='churn', session_id=42, fix_imbalance=True)
compare_models()
results = pull()  # 결과표 DataFrame
print(results[['Model', 'Recall']].sort_values('Recall', ascending=False))
# Out:
# <style type="text/css">
# #T_ffb86_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ffb86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffb86_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ffb86_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffb86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ffb86_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ffb86_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_ffb86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ffb86_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ffb86_row1_col1" class="data row1 col1" >churn</td>
#     </tr>
#     <tr>
#       <th id="T_ffb86_level0_row2" class="row_heading level0 row2" >2</th>
# ...
