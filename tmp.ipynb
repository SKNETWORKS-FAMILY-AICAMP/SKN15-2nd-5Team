# %%
import pandas as pd

# %%
df = pd.read_csv("./dataSet/ml_case_training_data.csv")

# %%
연간마진 = df["net_margin"] / df["num_years_antig"]

# %%
A = 연간마진

# %%
A = A.dropna()

# %%
import matplotlib.pyplot as plt
plt.boxplot(A, vert=True)
plt.title('Boxplot of values in Series A')
plt.xlabel('Value')
plt.grid(True)
plt.show()
